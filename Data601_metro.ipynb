# %%
#testing

# %%
#https://drive.google.com/file/d/1KxzIdZPXz58oKx0q401lAmFfYeKRP1qt/view?usp=sharing

url = 'https://drive.google.com/uc?export=download&id=1KxzIdZPXz58oKx0q401lAmFfYeKRP1qt'

# %%
import pandas as pd
# Load your data 
data = pd.read_csv(url)# Check out shape
print(data.shape)
data
# Out:
# (6, 13)
#    Year  January  February   March   April     May    June    July  August  \
# 0  2015   640312    636904  675563  733186  708360  738725  730448  657493
# 1  2016   572362    652227  657501  686226  648634  658794  629985  585666
# 2  2017   598844    603353  610211  642495  620874  657476  634216  595270
# 3  2018   563465    588633  582287  650173  629158  679265  644669  557335
# 4  2019   528473    585102  637846  664732  644470  663422  648749  601408
# 5  2020   630622    638794  310577   35629   38590   51985   61212   71030
#
#    September   October  November  December
# 0     660195  678908.0  638641.0  590580.0
# 1     617932  626120.0  570515.0  540187.0
# 2     620589  640113.0  602563.0  534319.0
# 3     616579  640793.0  591777.0  524600.0
# 4     661308  683145.0  630910.0  560329.0
# 5      83120       NaN       NaN       NaN

# %%
data.describe()
# Out:
#               Year        January       February         March          April  \
# count     6.000000       6.000000       6.000000       6.00000       6.000000
# mean   2017.500000  589013.000000  617502.166667  578997.50000  568740.166667
# std       1.870829   42554.888199   28701.867029  135635.91668  263187.531244
# min    2015.000000  528473.000000  585102.000000  310577.00000   35629.000000
# 25%    2016.250000  565689.250000  592313.000000  589268.00000  644414.500000
# 50%    2017.500000  585603.000000  620128.500000  624028.50000  657452.500000
# 75%    2018.750000  622677.500000  638321.500000  652587.25000  680852.500000
# max    2020.000000  640312.000000  652227.000000  675563.00000  733186.000000
#
#                  May           June           July         August  \
# count       6.000000       6.000000       6.000000       6.000000
# mean   548347.666667  574944.500000  558213.166667  511367.000000
# std    251612.422652  258017.019861  246281.941056  218187.980861
# ...

# %%
import matplotlib.pyplot as plt

#data.plot('Year', 'April')
plt.plot(data)
plt.ylabel('Number of Entries')
# Out:
# Text(0, 0.5, 'Number of Entries')

# %% [markdown]
# # Analysis of Open AQ Data: Washington DC Metro Area
#
# ### This analysis will focus on examining the fluctuation of pollutants in the Washington DC Metro Area before the COVID-19 pandemic. The year range that will be examined includes 2017-2019.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as np

# %%
data = pd.read_csv(r'openaq.csv')
data
# Out:
#                    location                             city country  \
# 0      PG Equestrian Center  Washington-Arlington-Alexandria      US
# 1             HU-Beltsville  Washington-Arlington-Alexandria      US
# 2        McMillan Reservoir  Washington-Arlington-Alexandria      US
# 3             HU-Beltsville  Washington-Arlington-Alexandria      US
# 4        JAMES S. LONG PARK  Washington-Arlington-Alexandria      US
# ...                     ...                              ...     ...
# 65531    McMillan Reservoir  Washington-Arlington-Alexandria      US
# 65532    JAMES S. LONG PARK  Washington-Arlington-Alexandria      US
# 65533            DCNearRoad  Washington-Arlington-Alexandria      US
# 65534         HU-Beltsville  Washington-Arlington-Alexandria      US
# 65535             WIDEWATER  Washington-Arlington-Alexandria      US
#
#                         utc                      local parameter    value  \
# ...
